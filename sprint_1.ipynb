# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.set()

# %%
#Load the Data
red_wine_original = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv',sep=';')
white_wine_original = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv',sep=';')
red_wine = red_wine_original.copy()
white_wine = white_wine_original.copy()

# %%
white_wine.drop([0, 2781])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_wine.drop([0, 2783])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#print the first 10 and the last 10 records

white_wine.head(10)
white_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#chech the info and the shape 
white_wine.info()
white_wine.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# (4898, 12)

# %%
#observe if there are missing values

red_wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
red_wine.drop_duplicates
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#check for Descriptive Statistics for both red and white wine datasets
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#Pie chart for comparing quantities

count = [1599,4898]
wines = ['Red wine', 'white wine']
# Plotting data on chart
plt.pie(count, labels=wines, autopct='%.0f%%')

# Add title to the chart
plt.title('Comparison for quantities of White and Red wine')

# Displaying chart
plt.show()

# %%
#histplot

sns.histplot(data = red_wine, x= "quality_label",color='red', bins=10)
plt.xlabel('Distribution of Quality')
plt.ylabel('Count')
plt.ylim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
red_wine["quality_label"].value_counts()
# Out:
# quality_label
# medium    837
# low       744
# high       18
# Name: count, dtype: int64

# %%
white_wine["quality_label"].value_counts()
# Out:
# quality_label
# medium    3078
# low       1640
# high       180
# Name: count, dtype: int64

# %%
sns.histplot(data = white_wine, x="quality_label",color='grey', bins=20)
plt.xlabel('Distribution of Quality')
plt.ylabel('Count')
plt.ylim(0, 3500)
# Out:
# (0.0, 3500.0)

# %%
#Boxplot
sns.boxplot(x="quality_label",
                y="alcohol",
                data=red_wine)

plt.xlabel('Wine Quality Class')
plt.ylabel('Wine Alcohol %')
# Out:
# Text(0, 0.5, 'Wine Alcohol %')

# %%
sns.boxplot(x="quality_label",
                y="pH",
                data=red_wine)

plt.xlabel('Wine Quality Class')
plt.ylabel('Wine pH')
# Out:
# Text(0, 0.5, 'Wine pH')

# %%
#Compare the correlation between the residual sugar and quality of red and white wine and also it leads to higher alcohol
#

# %%
# Basic heat map to show correlation between features. 

plt.figure(figsize=(12,8))

data = red_wine_original.corr()

mask = np.triu(np.ones_like(data.corr()))

sns.heatmap(data, annot=True, cmap='Spectral', vmax=1, vmin=-1, mask = mask)

plt.show()

# %%
plt.figure(figsize=(12,8))

data = white_wine_original.corr()

mask = np.triu(np.ones_like(data.corr()))

sns.heatmap(data, annot=True, cmap='Spectral', vmax=1, vmin=-1, mask = mask)
#sns.set(rc = {'figure.figsize':(20,10)})

plt.show()

# %%
from scipy import stats

F, p = stats.f_oneway(red_wine[red_wine['quality_label'] == 'low']['alcohol'],
red_wine[red_wine['quality_label'] == 'medium']['alcohol'],
red_wine[red_wine['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 205.23448800361507 	p-value: 4.776936653588672e-80

# %%
# For the presentation 
#scatter plot_white wine

sns.scatterplot(data=white_wine, x='alcohol', y='residual sugar', hue='quality_label',style = 'quality_label', sizes=(100, 100),size = 'quality_label', legend="full", palette="deep")
# Out:
# <Axes: xlabel='alcohol', ylabel='residual sugar'>

# %%
# For the presentation 
#scatter plot_red wine
sns.scatterplot(data=red_wine, x='alcohol', y='residual sugar', hue='quality_label',style = 'quality_label', sizes=(100, 100),size = 'quality_label', legend="full", palette="deep")
# Out:
# <Axes: xlabel='alcohol', ylabel='residual sugar'>

# %%
sns.lmplot(data=white_wine, x='residual sugar', y='alcohol')
# Out:
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=red_wine, x='residual sugar', y='alcohol')
# Out:
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.lineplot(data = red_wine, x="alcohol",y= "residual sugar", hue = "quality_label")
# Out:
# <Axes: xlabel='alcohol', ylabel='residual sugar'>

# %%
sns.jointplot(data = red_wine, x="alcohol",y= "residual sugar", hue= "quality_label")

# %%
# we are creating a new column called "alcohol_level", we define a range and associate that range with a label
red_wine['alcohol_level'] = red_wine['alcohol'].apply(lambda value: 'low'
if value <= 10 else 'medium'
if value <= 13 else 'high')
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['alcohol_level'] = pd.Categorical(red_wine['alcohol_level'],
categories=['low', 'medium', 'high'])
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.lmplot(data=red_wine, x = 'residual sugar', y =  'alcohol',hue='alcohol_level')
# Out:
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=red_wine, x = 'residual sugar', y =  'quality', hue='quality_label')
# Out:
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data= white_wine, x = 'residual sugar', y =  'quality', hue='quality_label')
# Out:
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
white_wine['alcohol_level'] = white_wine['alcohol'].apply(lambda value: 'low'
if value <= 10 else 'medium'
if value <= 13 else 'high')
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_wine['alcohol_level'] = pd.Categorical(white_wine['alcohol_level'],
categories=['low', 'medium', 'high'])
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
sns.lmplot(data=white_wine, x = 'residual sugar', y =  'alcohol',hue='alcohol_level')
# Out:
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=red_wine, x = 'residual sugar', y =  'alcohol',hue='alcohol_level')
# Out:
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/gurpreetsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from scipy import stats

F, p = stats.f_oneway(red_wine[red_wine['alcohol_level'] == 'low']['residual sugar'],
red_wine[red_wine['alcohol_level'] == 'medium']['residual sugar'],
red_wine[red_wine['alcohol_level'] == 'high']['residual sugar'])
print('ANOVA test for mean residual sugar across wine samples with different alcohol levels')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean residual sugar across wine samples with different alcohol levels
# F Statistic: 3.4581514259279995 	p-value: 0.03172405625024514

# %%
F, p = stats.f_oneway(red_wine[red_wine['quality_label'] == 'low']['residual sugar'],
red_wine[red_wine['quality_label'] == 'medium']['residual sugar'],
red_wine[red_wine['quality_label'] == 'high']['residual sugar'])
print('F Statistic:', F, '\tp-value:', p)
# Out:
# F Statistic: 0.011800296751587022 	p-value: 0.9882691399198739

# %%
F, p = stats.f_oneway(white_wine[white_wine['alcohol_level'] == 'low']['residual sugar'],
white_wine[white_wine['alcohol_level'] == 'medium']['residual sugar'],
white_wine[white_wine['alcohol_level'] == 'high']['residual sugar'])
#print('ANOVA test for mean residual sugar across wine samples with different alcohol levels')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean residual sugar across wine samples with different alcohol levels
# F Statistic: 569.1353934399872 	p-value: 5.843890240725404e-223

# %%
F, p = stats.f_oneway(white_wine[white_wine['quality_label'] == 'low']['residual sugar'],
white_wine[white_wine['quality_label'] == 'medium']['residual sugar'],
white_wine[white_wine['quality_label'] == 'high']['residual sugar'])
print('F Statistic:', F, '\tp-value:', p)
# Out:
# F Statistic: 21.934773835107606 	p-value: 3.2830889157949124e-10

# %%
sns.boxenplot( data=red_wine, y = 'residual sugar', x=  'quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='residual sugar'>

# %%
sns.boxenplot( data=white_wine, y = 'residual sugar', x=  'quality_label',).set_ylim(0,30)
# Out:
# (0.0, 30.0)

# %%
white_wine['alcohol_level'] = white_wine['alcohol'].apply(lambda value: 'low'
if value <= 10 else 'medium'
if value <= 13 else 'high')
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine['alcohol_level'] = red_wine['alcohol'].apply(lambda value: 'low'
if value <= 10 else 'medium'
if value <= 12 else 'high')
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.jointplot(data = red_wine, x="alcohol",y= "residual sugar", hue= "alcohol_level",ylim=(0,20))

# %%
sns.jointplot(data = white_wine, x="alcohol",y= "residual sugar", hue= "alcohol_level",ylim=(0,30))
